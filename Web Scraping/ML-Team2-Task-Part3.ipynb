# %% [markdown]
# # Import necessary modules

# %%
import requests
import bs4 as bs
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import pandas as pd

# %% [markdown]
# # Page URL

# %%
# Storing the url
url = 'https://forums.t-nation.com/top'

# %%
# Creating a new Chrome Session for Selenium
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(executable_path="./chromedriver_linux64/chromedriver", options=options)
driver.implicitly_wait(2)
driver.get(url)

# %% [markdown]
# # Titles

# %%
# Scraping the whole page 
page = driver.execute_script('return document.body.innerHTML')
soup = bs.BeautifulSoup(''.join(page), 'html.parser')

# %%
title = soup.find_all("a", {"class": "title raw-link raw-topic-link"})
list_of_titles=[]

# %%
for item in title:
    list_of_titles.append(item.get_text().strip())
list_of_titles
# Out:
# ['Today’s Article “High Rep Deadlifts are Dead”',
#  'Ran Building the Monolith! Write-Up/Thoughts',
#  '26 Months of Full Effort Applying Everything I Have Read on T Mag Since 1998',
#  'A Friendly Challenge - Battling Program ADD',
#  'Words That Bear Repeating: Community Wisdom',
#  'Got Asked “Excuse Me Sir, Do You Lift Weights?”',
#  'COVID19: Perspective From A (Sort Of…) Expert-Adjacent Person',
#  'Show Off Your Pets',
#  'Meet Recap - 1840.8 lb Total at 239 lb BW',
#  'Official 2020 T-ransformation Announcement Thread',
#  'I’m Getting Worried: The Erosion of Our Rights',
#  'Leg Day is for you Ambulating Fools',
#  'A Simple Program',
#  'Flame Free Confession III: Even More Flame Free',
#  'Merry Christmas',
#  'Some Insight with a Client that is Crushing it Right Now',
#  'SkyzykS’s Keep Hitting It Until It Works Again Log',
#  'Upcoming Interview with physiolojik',
#  'Things That Make You Happy',
#  'New Interview Online',
#  'Deadlift Challenge: 100 Reps of 225lbs for Time',
#  'HGH Cut With Zero Cardio 90 Day Update',
#  'Does Training Volume Get A Bad Rap?',
#  'Signs That You’re Training Like a Big Girl’s Blouse',
#  'Feb ‘20 Photo/Video Check-In',
#  'August ‘19 Photo/Video Check-In',
#  '2020: IronOne Levels Up',
#  'Now I Have a Machine Gun, Ho-Ho-Ho',
#  'Best Option for a Lagging Bodypart',
#  'I’m Embarrassed by Americans, Disgusted Even',
#  '“It’s Just the Flu, Bro!”',
#  'Venturing Into The Meadows And Dropping A Gamma Bomb(ChongLordUno)',
#  'Greetings, Excellent Forum',
#  'Rewind to 10th Grade',
#  'Anna’s Training Log Part 2',
#  'Mr Olympia 2019',
#  'Stop “Locking Your Scapula Down”',
#  'Sick of Gym Members Sitting on Equipment Playing with Their Phones',
#  'Do I Look Like I’m on Roids?',
#  'Tom Stoltman 286kg/629lb Atlas Stone Load',
#  'TRT Credentials Thread',
#  'John’s Training Log - Road to 225-315-405',
#  'Men and Women, Women and Men',
#  'You Know You’re Asian When',
#  'Benefits of Estrogen for TRT Patients',
#  'Coronavirus - What Happened?',
#  'MarkKO’s Training Log II',
#  'What Are You Thankful For 2019',
#  'Queen Cobra’s Training Log',
#  '40, Nothing to Show for It',
#  'Barbells, Beer and Bob: How to Old',
#  'The Systemlord Callout Thread',
#  'Favorite Training Accomplishments?',
#  'TRT Facts - Beyond Bro-Science',
#  'Natural Bodybuilding Stats and Gains',
#  '5/3/1 BBB Training Log',
#  'Ripped before 30 (Aldebaran)',
#  'At 4:20 on 4/20/2020 There Will Be 4 20’s, So Let’s Deadlift',
#  'Took a 20 Year Hiatus, Contest in May',
#  'Joe Rogan Experience - Ronnie Coleman',
#  'HGH: A How-To Guide',
#  'Brag’s Powerlifting Journey',
#  'Calisthenics for 6 Months, Progress Slower Than What is Normal',
#  '“Mac” On Getting Jacked For “Sunny”',
#  'Injection Frequency - Pharmacokinetics Perspective',
#  'Regrets on Focusing Too Much on Working Out?',
#  'Happy Marriages/Relationships',
#  'Vonko1988 TRT Log',
#  'Any Jobs Available In T-Nation?',
#  '90’s Bodybuilding Was Pretty Damn Good',
#  'Will I Look Big Once I Reach Jason Blaha’s Strength Standards?',
#  'Lunge Challenge 2.0: Half-Mile/Full Mile',
#  'Let’s Talk Writing',
#  'Molyneux on Incels',
#  'New Deadlift WR',
#  'Do I Look Like I Even Lift?',
#  'Everything You CAN Do with Minimal Equipment',
#  'Iron Mafia Thirst Performance Bragging Rights Meet Recap',
#  'The T-ransformation 2020 Results',
#  'Epic Movie Soundtracks',
#  'The Impeachment Hearings',
#  'Eddie Hall Won’t Recognize Thor’s Deadlift Record',
#  'Trainer Never Heard of 5/3/1. How Should I Have Reacted?',
#  'First-Timers: Read This First',
#  'Results So Far. Low Dose Anadrol',
#  'Why the Trap Bar Deadlift is Completely Useless',
#  'Julius Maddox 800lb Bench?',
#  'Home Workout Without Equipment?',
#  'Timber’s White Brick Chronicles',
#  'I’d be Very Careful with “No AI” Advice',
#  'Finished 100-Hour Modified Fast. Experience Write-Up',
#  'Who Are Your Favorite Actors?',
#  'A Question About Alleged Natural Contests',
#  'John Meadows in Hospital',
#  'Ground Beef as Main Protein Source: Bad?',
#  'Would 5/3/1 BBB Be Junk Volume?',
#  'I Need Help with Getting My Dream Body',
#  'Why Do Powerlifters Scream Before a Lift at a Meet? Ego Thing?',
#  'China’s Dangerous Lies about Everything',
#  'George Floyd Riots',
#  'Lex Luger Talks Steroids',
#  'Advice for an Endomorph? Looking to Compete in Classic Physique',
#  'Unable to Get Good Sleep, Noisy Roommates',
#  'Don’t Drink, Just Lift',
#  'The Investing Thread (Coronavirus Edition)',
#  'Franco Columbu RIP',
#  'The War on Drugs',
#  'My 21 Y/O Fiancee’s Metabolism is Absolutely Horrible and I Don’t Know What to Do',
#  'How Has Covid Affected You?',
#  'Are You Suppose to Get Weaker on Candito 6 Week Intermediate Program?',
#  'Dbossa, Interviews About AIs?',
#  'Best Cut Cycle Ever Log',
#  'White Supremacy: “A Hoax”?',
#  'Measurement of Free Testosterone',
#  'Clueless Lifter',
#  'Considering Self-Prescribing TRT If Doctor Won’t Help. Opinions?',
#  'Cstan097’s Training Log',
#  '2019 NFL Thread',
#  'Stopped Doing Accessory Work',
#  'Giving Bodybuilders A Bad Name',
#  'Apparently Bodybuilders Are Not Very Strong',
#  'Nothing Annoys Me More than Some Guys on Tren at the Gym',
#  '“14 Common Features of Fascism”',
#  'Hardartery - Almost As Big As Your Mom',
#  'No Nut November',
#  'From GarageRocker’s Basement',
#  'ELITEFTS Has Cut All Ties With Metal Powerlifting Over Comments Made By Its Founder',
#  'SB’s Upcoming Blast',
#  'How Has Your Training Evolved?',
#  'Lunge Challenge: Bodyweight on Bar',
#  'Lethal Force Discussion',
#  'Farmer’s Carry Challenge, Bodyweight for Max Distance',
#  '“Being Openly Conservative is Harder Than Being Gay”, Is She Kidding?',
#  'Larry Wheels Powerlifting Comeback Meet',
#  'DarkDescartes TRT Recovery Log',
#  'Am I Turning Conservative?',
#  'Time to Start Logging',
#  'What is the Bro Split Training Division?',
#  'Female Bully Gets Punched Back',
#  'Most Important Credentials for Posting Training Advice?',
#  '“The Game Changers” Plant-Based Nutrition Movie. Thoughts?',
#  'Fights In the Gym?',
#  'Unexplained & Persistent Missing Libido',
#  'How Do I Know When I Stop Making Beginner Strength Gains?',
#  'Eddie Hall Eyeing Up Raw Bench Press WR',
#  'New to TRT, Unique Case to Say the Least',
#  'Jordan Peters Already Ditches the “RIR High Volume” Training',
#  'Does Using More Stabilizers Lead to More Hypertrophy?',
#  'DexterMorgan’s log - TRT, Lifting, Mental Health, Vaginal Attainment',
#  'Larry Wheels Accused of Physical and Verbal Abuse',
#  'Powerlifting Max Bench Arch',
#  'Poll: The Ultimate Dilemma - Bigger or Leaner',
#  'Robert Pattinson Refuses to Train for Batman',
#  'Approaching People on the Gym Floor to Get Help',
#  'Best Program for an Early-Intermediate Bodybuilder?',
#  'What Would You Do If You Were Me - Bulk or Lose More Fat?',
#  'Stopping TRT After 2 Years. PCT Advice?',
#  'What’s the Process for Bodybuilding/Physique Coaching Like?',
#  'How I Stay at 8% Bodyfat Year Round',
#  'I Don’t Get the “Eat, Eat, Eat” Advice',
#  'End of CrossFit?',
#  'Dieting 8 Weeks. How to Keep Seeing Results?',
#  'How to Ask People What They’re Training?',
#  'Oral Only First Cycle: Dianabol and Anavar',
#  'Why Measuring Serum Levels of Estradiol (E2) is Pointless',
#  'T-Nation is the Most Vegan, Non-Vegan Website',
#  'Who’s Going To Break The Raw Deadlift Record?',
#  'How to Add Mass to Back?',
#  'How Do You Flirt with Women?',
#  'What’s your Free-Testosterone?',
#  '15 Years Old, Lifting 6 Months. How Are My Stats?',
#  'Are Single-Joint Exercises Really Worthless?',
#  'HCG - 12 Week Case Study',
#  'Video: Natural vs Enhanced (How to Train)',
#  'Gym Etiquette for Waiting for Equipment?',
#  'E3D Protocol Log',
#  'TouchinDeez’s TRT Log',
#  'Would You Rather LOOK Strong, or BE Strong?',
#  'I Need Help With My Physique',
#  'Teen Bulk or Cut?',
#  'What You Enjoy Vs What Supports Your Goals',
#  'Eggs, Egg Whites and More Eggs',
#  'kuda’s Training Log',
#  '18 Years Old, 5’5”, Wanting to Compete in Classic',
#  'Strong Squat and Deadlift, Weak Bench?',
#  'Everybody’s Trying To Do The Right Thing, It’s Just Coming Out Wrong',
#  'Returning to the Mats (Free-Style/Greco Wrestling)',
#  '160lbs to 145lbs Cut… Will My Abs Ever Show?',
#  'Don’t Go Commando with Titan Triumph Singlet!',
#  'I Threw My Second Chance at Life Away Because I Went Bowling',
#  'The Quest For Fullsterkur',
#  'Struggling With Turning 30',
#  'Tlaib and Omar Barred from Israel',
#  'TRT Protocols, HCG or No HCG?',
#  'Why Do You Like Where You Live?',
#  'Not Feeling Kroc Rows in Back',
#  'T-Ransformation 2020: Atlas is too fat',
#  'World’s Strongest Man General Discussion',
#  'Beginner Protocol Sticky Recommendation',
#  'I Hate This Time Of Year In The Gym',
#  'Jibb’s Garage Training Log',
#  'At Long Last, My Primo Blast',
#  'Weird to Find Laura Phelps Attractive?',
#  'Ice Baths for Fat Loss with No Exercise/Diet/Discipline',
#  'To Lift The Husafell Stone',
#  'Dorian on the Current Mr. Olympia',
#  'My Honest Experience With Testosterone (TRT)',
#  'TRT Not Working',
#  'Advice About a Co-Worker',
#  'This Coffee Fad',
#  'Trenbolone Pharmacological Explanation',
#  'Superhero Muscle x 3',
#  'TRT Facebook Drama',
#  '36 Y/O. How Can I Improve?',
#  'Another Anti-AI Post with Test Results',
#  'People Pretending to Win Money',
#  'Return of the Muskrat, Vol. 2',
#  'Old Wannabe Offended By Chalk?!',
#  '18y/o 280kg Easy Deadlift at 100kg. Lockout Advice?',
#  'What Are Signs That One’s Therapeutic Dose is Too High?',
#  'Diagnosed with Uncontrolled Type 2 Diabetes',
#  'Peaking for Comp This Week, Body Didn’t Change After Carb Load Day. Advice?',
#  'Test/Dbol Cycle Log',
#  'Half Inch Arm Loss',
#  'Anxiety and Irritability Getting Worse on TRT',
#  'Is Anyone Worried That Coronavirus Is Going To Kill Their Gains?',
#  'Lifts are Stalling and I Don’t Know What Routine to Do Anymore',
#  '18 Yrs Old, 145 Pounds. First Cycle, Deca + Test E. Am I Missing Something?',
#  'Article: “Are You Strong?”',
#  'WPO Live Stream',
#  '4 Weeks On, 4 Weeks Off Cycles',
#  'Da March to Sixty',
#  'BPC-157 Results',
#  'Josht9210’s TRT Log - Depersonalization, Panic Disorder, Agoraphobia, Etc',
#  'Left, Right, No In Between',
#  '5’8”, 250, 21 Yr Old Strongman Competitor. First Cycle?',
#  'Anyone Here Ever Deal With Borderline Personality Disorder?',
#  'Craig Golias 6’3”, 350 lbs Ripped',
#  'Why So Many Views But Little Input?',
#  'Daniel Bell New ATWR Total 1142.5kg / 2517 lbs',
#  'Creatine Experiment',
#  '4 Plate Bench @100kg BW',
#  'Program and Hypertrophy Advice?',
#  'When is it Okay to Spend Money?',
#  'The Weird Things People Do',
#  'Joe Rogan Experience - Bernie Sanders',
#  'Suffering Low T 15 Years After Teenage Steroid Use, Labs Included',
#  'Lee Boyce’s Training Advice',
#  'What is Leadership?',
#  'Very Confused, Can’t Lose Weight',
#  'Jordan Syatt Youtube Channel',
#  'How to Cut Without Losing Muscle (Natural)',
#  'Semantics and Superiority',
#  '“I Hate That Gym” Venting Thread',
#  'Do People Mess with You More Because You’re Big?',
#  'Better for the Party: “Many Voices” or “STFU”?',
#  'Is it Necessary to Gain Weight to Lift Heavier?',
#  'Back in Business',
#  'Free Speech Now and in 2050 (Without Partisan Arguments)',
#  'Training for Size, and Evolution',
#  'Ready For First Cycle? (Test C, Bloodwork, TRT, Lots Of Research, Lots Of Details)',
#  'Rise of the Slaya 2020',
#  'How Do I Know I’m Gifted for Arm Wrestling?',
#  'An Annoying Truth About AAS Use: Scammers',
#  'Overtraining Possibly?',
#  'Big Dogs Live Stream',
#  'Bikini Prep: 31415 Days Out',
#  'Is Life a Punishment/Hell?',
#  'Log - 1st Cycle Test E',
#  '200mg to 140mg: What Are the Notable Differences?',
#  'Heavy Partial Lateral Raises',
#  'Do You Believe In A God? Why or Why Not?',
#  'Look What I Made - Wooden Monolift',
#  'How to Build Conditioning?',
#  'Will Barotti Benched 1105lbs',
#  'Video: Tested Squat vs Untested Squat WRs',
#  'Chronic Depression, Fatigue, No Libido All of My Life',
#  'How’s This Full Body Workout for Hypertrophy?',
#  'Ravenous Sexual Fantasies. Help?',
#  '2.5 Years on TRT and Never Got Better',
#  'Why is First Deadlift Rep the Hardest?',
#  'Need Help Running a Deca-Only Cycle',
#  '“Naturally Enhanced” Program?',
#  'Kai Greene- Current Shape May 2020',
#  'What am I Doing Wrong?',
#  'IPF Champion Of Champions Meet $300k + Prize',
#  'Low-Dose Nandrolone with Test for TRT?',
#  'Progress Pic Made Me Paranoid. What Am I Doing Wrong?',
#  'What Caused Ronnie Coleman’s Back Injury?',
#  'More Meat, More Power',
#  'Been on TRT for 5 Weeks and I’m Very Worried',
#  'Thoughts on UBI?',
#  '1 Cycle Only 8 Wk Pics',
#  'Ex-Competitive Lifter Who’s Lost All His Confidence. Need Advice',
#  '250mg Test Enanthate for 14-16 Weeks?',
#  'Rate My Conditioning: 110 lbs Female',
#  'Bas Rutten “Body Action System” Initial Impressions',
#  '20 Y/O, 5’7, 145lbs, 27-28 Inch Waist',
#  'Is T-Nation Bull?',
#  'Another Stuck At Home T-ransformation Log: JDM135',
#  '“Arnold Wants Drug Testing”',
#  'What % Bodyfat/Lean Muscle Do I Have?',
#  'What is This Face Mask Called?',
#  'Why Do Decent Amount of T Doses Mess Up My Libido and Erections?',
#  'What Would You Suggest for Insomnia?',
#  'First Blast on TRT - Test Cyp + Anavar?',
#  '4.25 x Bodyweight Deadlift',
#  'American Companies Caving to Chinese Censorship',
#  'At This Point in 2019, I’m Not Voting at All',
#  'I’m Never Hungry',
#  'Powerlifters Who Cycle in the Off-Season Then Compete TESTED?',
#  'Question for Any Lawyers?',
#  'Thanks Paul for the Tips on Lats',
#  '325x5 Conventional DL: Potential 405 Sumo?',
#  'Beginner, Recommendations?',
#  'Testosterone Increase Action Plan',
#  'BBB 3 Month Challenge: Optional Exercises/1RM/Weight Questions',
#  'Cut or Bulk First?',
#  'Long Term Approach - Low Volume/Frequency?',
#  'Danny Bossa, a Question if You Please',
#  'Epstein and “The Lolita Express”',
#  'Can You Take Winstrol Without Test?',
#  'How Fast Do Testicles Shrink on Steroids?',
#  'Little Experiment: EQ and Mast',
#  'My 50 Y/O Log: And lots of rambling talk',
#  'Barbell-Only Workout?',
#  'Whats in Your Garage Gym?',
#  'Stopped AI, Doing Better',
#  'Tren: “The Heaviest and Most Taxing on Your Body”',
#  'Crisis-Related Job Loss',
#  'What Do You Guys Do When You Can’t Get It Up?',
#  'Anyone Taking Armour Thyroid? Feedback?',
#  'Squat: Hips Shooting Back Enough to Be Told to Re-Rack it ASAP?',
#  'Finasteride Sides 10 Years Later',
#  'Is a Set Over If You Let Go of the Bar for a Few Seconds?',
#  '125mg E5D. Side Effects with AI and Aromasin',
#  '23 Yrs Old, 6’, 206lbs. 6 Years Progress - Critique?',
#  'Weaning Off My AI Experiment Log',
#  'Chieftain’s 2020 Transformation Log',
#  'BDWP: Is Low Volume Enough? Realistic Gains at 41? When to Progress to Part 2?',
#  'Yury Belkin Takes 110kg Raw Total World Record',
#  'Combat/Self Defense BJJ',
#  'Going to Urologist on Thursday Morning',
#  'Virginia to Outlaw Martial Arts Instruction',
#  'Started TRT This Week. Tired and Dragging',
#  'Huge Improvement in Labs. Still Feel Like Crap',
#  'Danielle’s Training Journal',
#  'How You Should Actually Take Your Oxandrolone',
#  'Ever Envy Full-Time Bodybuilders/Lifters?',
#  'Things You Wish Existed',
#  'Article. No One Is Born in ‘The Wrong Body’',
#  'Why Is No One Benching Like the Golden Era Guys Anymore?',
#  'Sheiko Gold: AI Powerlifting Coaching App',
#  'Where is KSman?',
#  'Squat Form Check',
#  'What are Your Best & Worst Bodybuilding Poses & Why?',
#  'Distal Bicep Tendon Rupture',
#  'Low SHBG - how much Testosterone?',
#  'So… I’m Wooing a Lady. How will this Work?',
#  'NOT a First Amendment Issue, Folks!',
#  '5x5 FSL and BBB - Eating to Win',
#  'Help Resolve Confusion with Transition from GSLP to 531',
#  'Can I Get Good Results from 300mg of Test a Week?',
#  'Remington and Sandy Hook',
#  'Training for Long Term Weight Cut',
#  'Changes to Make to My Diet for Gains?',
#  'Who Grows a Fruit/Veg Garden?',
#  'Really Struggling Dialing in TRT',
#  'Cardio While Bulking?',
#  'What Should I Do? (D1 Athlete)',
#  '“The Republic is Dead”',
#  '2 Decades of Body Abuse Followed by 6 Months of Fitness',
#  'Psychological/Mental Effects of TRT',
#  'Fat, A Smoker, and Out of Gym',
#  'Primer52 for Naturals?',
#  'Introduction and a Request for Advice on How to Be Big',
#  'Is This Forum Mainly Anti-AI While on TRT?',
#  'What is My Best Possible Bench?',
#  'Normal Estradiol Range?',
#  '2nd Cycle - Yikes',
#  'Low T, New to TRT',
#  'Not Feeling Good After One Year on Test E',
#  'Adding a Compound for Fat Loss. Advice?',
#  '15 YO Attempts to Mug a Cop with Fake Gun, Gets Shot - First Degree Murder?!',
#  'To Salt or Not to Salt?',
#  'Another Deca Dick Thread',
#  'Deadlift Grip Strength?',
#  '350mg Test C Only Cycle Log with Pictures',
#  'How has TRT Affected Your Spouse/Girlfriend, Kids?',
#  '82.5kg / 181 lb World Record Deadlift?',
#  'Not Everyone Wants to Compete or Have Fame?',
#  'Chronic Fatigue Syndrome',
#  'High E2 Symptoms?',
#  'Where Can I Meet More Mature People?',
#  'TRT Log: Dialing In Still, Desperately Need Help - ED Issues',
#  '5/3/1 and Conditioning for First Responders',
#  'Training Twice a Week Full Body vs Push/Pull/Legs?',
#  'Adding NPP to TRT',
#  'Brickhoss1 Journal Update: 42mg EOD SubQ. Still Dialing In. Elevated TSH, Prolactin, E2',
#  'Lifting for Fat Loss',
#  'Absolutely No Sex Drive',
#  '1 Month on New Protocol, Erectile Dysfunction Not Improving',
#  'DNP + Tren + Test + EQ + Clen',
#  'Started Stronglifts 5x5',
#  'Training Percentages Changed with Age/Injuries',
#  'Come Laugh at My Relationship',
#  'First Cycle, Test E',
#  'What Motivates You to Lift Weights?',
#  'Trump and Tulsa-WTF?',
#  'Laymans TRT Log/Diary - Bodybuilding/Healing IBD/Autoimmune',
#  'Tried Every Protocol. Started Every Day Injections',
#  'First and Only Cycle',
#  '1000-1500 Calorie Smoothies/Shakes',
#  'Why Hasn’t There Been a 600 LB C&J and 500 LB Snatch Yet?',
#  'Mandatory Training For LEO, Military, Security, Etc',
#  'What is Yury Belkin’s Training?',
#  'High Estrogen Effects (Labs compared to Symptoms)',
#  'First Time on an AI on TRT. Your Opinions?',
#  'Looking to Start My First Cycle',
#  '3 Weeks Out from Physique Show, Diet Advice?',
#  '6 Months of Ineffective TRT; Latest Labs Posted. What Next?',
#  '‘Doctors Should Prescribe TRT Only for Sexual Dysfunction’',
#  'Tren Dick for About a Year and a Half',
#  'SubQ and Feel Like I Quit TRT',
#  'Krypteia Redux! Awesome',
#  'Primer 52 - Sample Workouts?',
#  'Blast and Cruise: Less Response/Gains Over Time?',
#  '59 Years Old/Young, Just Started Working Out',
#  'Take 2, Show in August',
#  'New Protocol From New Doctor',
#  'Testosterone Enanthate, First Injection',
#  'Article - The Politics of Procreation',
#  'Weight Gain and Water Retention on TRT',
#  'Salt Pre-Workout',
#  'Is My Program Good for Me? (Hardgainer)',
#  'E2 Penile Sensitivity',
#  'Should I Lose More Weight?',
#  '18 Yrs Old, Finished First Cycle. Having Problems',
#  'Big Butt Problems',
#  '34 Year Old w/ Low T for a while. Need Advice on TRT',
#  'In Search of Tried and True Advice/Educational Resources',
#  'Your Gym Playlist',
#  'Keeping the Spine Healthy',
#  'HGH Peptide for My Teen Son?',
#  'Push/Pull/Legs the Ultimate Split Article vs “Don’t Train 6x Per Week”?',
#  'When Will Sex Drive Kick In?',
#  'Squat 100 LBS per Decade',
#  'Best Minimal Work for Strength Retention?',
#  'When and Why Do Straight Sets for Hypertrophy?',
#  'New Tool Music on Spotify',
#  'Suggestions on a New Program?',
#  '10kg to Lose for Feb 9th Meet. Tips?',
#  'Study: Injection Frequency, Not Dosage, Indicates Risk of Polycythemia',
#  'Help with Current TRT Dosage, Possible Side Effects',
#  'Holidays Negate Calories, Right?',
#  'Opinion on Bodyweight Exercises for Muscle Gain?',
#  'Crashed E or High E?',
#  'What Does Elevated Progesterone Mean in Men?',
#  'Information About Nandrolone?',
#  'Reducing LDL Cholesterol',
#  'Need Help with My Bench',
#  'Heard of Ivo Toledo? Physique Competitor',
#  'My 8 Year Transformation - Becoming a Physique Champion',
#  'Can I Do it Natty or Do I Need Gear?',
#  'Skullcrushers vs Close Grip Bench for Tricep Growth?',
#  'Test and Deca, Lost Libido Unresponsive Dick and Emotionally Flat',
#  'Losing Strength?',
#  'Socialist Democrats Convention',
#  'Ashwagandha, Damn!',
#  'Strength Training Frequency?',
#  'Anyone Taking Daily Cialis Long Term?',
#  '100% New to Weightlifting',
#  'Advice for 2nd Cycle?',
#  'Help Designing 12-Week Conjugate Block?',
#  '2 Weeks Into Test Cycle, Sexual Side Effects',
#  'Differences Between Front Squat vs Back Squat?',
#  'Subq vs IM Injections',
#  'Training for the Ultimate Heist',
#  '22 Y/O Almost 120kg…Am I Fat?',
#  'Bloodwork After 7 Weeks on TRT (High TT Low FT)',
#  'Here2log’s 2020 T-ransformation',
#  'The Chicken Sandwich Wars',
#  'My Numbers after 30 Days on TRT',
#  'Dealing with People Who “Know Someone Bigger/Stronger” Than You',
#  'Anavar as a Finisher if Over 15% BF?',
#  'NPP Dosages For Gaining Twenty Pounds',
#  'Do You Discuss Your Steroid Use with Anyone?',
#  'Update: Mood Issues when on Injection',
#  'What is the Deep State Goal?',
#  'How Much Test Do You Guys usually Cruise On?',
#  '‘Best’ T-Nation Topics',
#  'Preparing for Middle Age',
#  'Minimum Cycle for Big Gains, Tren-Test?',
#  'What to Do When a Calorie Deficit Isn’t Burning Fat?',
#  'Need Advice (Very New to This)',
#  'Get Your Act Together',
#  '“Test E” First Cycle?',
#  'How to Look Bloated and Terrible for “Before” Photo?',
#  'What Do You Guys Foresee as the “New Norms”?',
#  'When to Stop a Set?']

# %% [markdown]
# # First reply under the title

# %%
#no of replies
replies=[]
for i in list_of_titles:
    try:
        link = driver.find_element_by_link_text(i)
        link.click()
        value=driver.find_element_by_xpath("""/html/body/section/div/div[2]/div[2]/div[4]/div[3]/section/div[1]/div[2]/div/div[1]/article/div/div[2]/div[2]/div""").text
        replies.append(value)
    except:
        pass
    driver.back();

# %%
replies
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-462f3861e2b8> in <module>
# ----> 1 replies
#
# NameError: name 'replies' is not defined
